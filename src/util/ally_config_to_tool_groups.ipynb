# %%
#!datamodel-codegen  -h

# %%
#!datamodel-codegen  --url https://ally-config-ui.dev.copilot.aws.inform-cloud.io/openapi.json --input-file-type openapi --output ally_config_api_models.py

# %% [markdown]
# # OpenAPI to Pydantic-AI Tools - Complete Demo
#
# This notebook demonstrates the complete workflow for converting OpenAPI specifications into pydantic-ai tools.

# %%
## Step 1: Load the OpenAPI Tools

from lib.openapi_to_tools import OpenAPIToolsLoader

# Initialize the loader
loader = OpenAPIToolsLoader(
    openapi_url="https://ally-config-ui.dev.copilot.aws.inform-cloud.io/openapi.json"
)

# Load all tools
print("Loading tools from OpenAPI spec...")
tools = loader.load_tools()

print(f"\n✅ Successfully loaded {len(tools)} tools!")
print(f"\nFirst 5 tools:")
for i, tool in enumerate(tools[:5], 1):
    print(f"  {i}. {tool.name}")
# Out:
# Loading tools from OpenAPI spec...
# Created tool: get_aws_logs_api_getAWSLogs_post [POST /api/getAWSLogs]
# Created tool: get_capabilities_api_capabilities_get [GET /api/capabilities]
# Created tool: get_active_config_api_getActiveConfig_post [POST /api/getActiveConfig]
# Created tool: validate_config_api_validateConfig_post [POST /api/validateConfig]
# Created tool: set_config_api_setConfig_post [POST /api/setConfig]
# Created tool: get_config_history_api_getConfigHistory_post [POST /api/getConfigHistory]
# Created tool: create_endpoint_api_createEndpoint_post [POST /api/createEndpoint]
# Created tool: get_endpoint_metadata_api_getEndpointMetadata_post [POST /api/getEndpointMetadata]
# Created tool: update_endpoint_metadata_api_updateEndpointMetadata_post [POST /api/updateEndpointMetadata]
# Created tool: delete_endpoint_api_deleteEndpoint_post [POST /api/deleteEndpoint]
# Created tool: get_endpoints_api_getEndpoints_post [POST /api/getEndpoints]
# Created tool: get_endpoint_authorization_api_endpoint_authorization_get [GET /api/endpoint/authorization]
# Created tool: update_endpoint_authorization_api_endpoint_authorization_post [POST /api/endpoint/authorization]
# Created tool: delete_endpoint_authorization_api_endpoint_authorization_delete [DELETE /api/endpoint/authorization]
# Created tool: execute_evaluation_suite_api_executeEvaluationSuite_post [POST /api/executeEvaluationSuite]
# Created tool: get_stored_evaluation_results_api_getStoredEvaluationResults_post [POST /api/getStoredEvaluationResults]
# Created tool: get_evaluation_suites_api_getEvaluationSuites_post [POST /api/getEvaluationSuites]
# Created tool: get_evaluation_suite_by_name_api_getEvaluationSuiteContentsByName_post [POST /api/getEvaluationSuiteContentsByName]
# Created tool: get_evaluation_suite_history_by_name_api_getEvaluationSuiteHistoryByName_post [POST /api/getEvaluationSuiteHistoryByName]
# Created tool: create_evaluation_suite_api_createEvaluationSuite_post [POST /api/createEvaluationSuite]
# Created tool: add_test_cases_to_evaluation_suite_api_addTestCasesToEvaluationSuite_post [POST /api/addTestCasesToEvaluationSuite]
# Created tool: save_evaluation_suite_api_saveEvaluationSuite_post [POST /api/saveEvaluationSuite]
# Created tool: get_cost_graph_snapshot_api_getCostGraphSnapshot_post [POST /api/getCostGraphSnapshot]
# Created tool: get_cost_per_day_api_getCostPerDay_post [POST /api/getCostPerDay]
# Created tool: get_permissions_api__resource_type__permissions_get [GET /api/{resource_type}/permissions]
# Created tool: add_role_api__resource_type__role_post [POST /api/{resource_type}/role]
# Created tool: remove_role_api__resource_type__role_delete [DELETE /api/{resource_type}/role]
# Created tool: grant_permission_api__resource_type__role_permission_post [POST /api/{resource_type}/role/permission]
# Created tool: revoke_permission_api__resource_type__role_permission_delete [DELETE /api/{resource_type}/role/permission]
# Created tool: add_user_api__resource_type__role_user_post [POST /api/{resource_type}/role/user]
# Created tool: remove_user_api__resource_type__role_user_delete [DELETE /api/{resource_type}/role/user]
# Created tool: get_ratings_aws_api_getRatingsAWS_post [POST /api/getRatingsAWS]
# Created tool: get_session_histories_api_getSessionHistories_post [POST /api/getSessionHistories]
# Created tool: get_available_AI_models_api_getAvailableAIModels_post [POST /api/getAvailableAIModels]
# Created tool: get_scopes_api_getScopes_post [POST /api/getScopes]
# Created tool: upload_file_to_S3_api_uploadToS3_post [POST /api/uploadToS3]
#
# ✅ Successfully loaded 36 tools!
#
# First 5 tools:
#   1. get_aws_logs_api_getAWSLogs_post
#   2. get_capabilities_api_capabilities_get
#   3. get_active_config_api_getActiveConfig_post
#   4. validate_config_api_validateConfig_post
#   5. set_config_api_setConfig_post

# %%
## Check out Tool Definitions
for tool in tools:
    print(f"{tool.tool_def}")
# Out:
# ToolDefinition(name='get_aws_logs_api_getAWSLogs_post', parameters_json_schema={'type': 'object', 'properties': {'log_group': {'type': 'string', 'title': 'Log Group', 'description': 'Log group in AWS'}, 'session_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Session Id', 'description': 'Session ID for filtering logs'}, 'start_time': {'type': 'string', 'title': 'Start Time', 'description': 'Start time for log retrieval'}, 'end_time': {'type': 'string', 'title': 'End Time', 'description': 'End time for log retrieval'}}, 'required': ['log_group', 'start_time', 'end_time'], 'additionalProperties': False}, description='Retrieve AWS log data.\n\nThis function retrieves log data from a specified AWS log group, filtering\nthe logs based on session ID and time range.  It returns a list of log\nentries along with a dictionary of session IDs and their corresponding\ntimestamps.\n\nReturns:\n    A response containing the log data and session IDs.\nRaises:\n    NoSuccess: If the log group is not found or if there are issues with\n        retrieving the logs.')
# ToolDefinition(name='get_capabilities_api_capabilities_get', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Route to get configuration parameters of the Ally Portal.\n\nReturns:\n    CapabilitiesResponse: Contains Keycloak server URL, realm, client ID,\n                          Ally server domain, and AI knowledge host.')
# ToolDefinition(name='get_active_config_api_getActiveConfig_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'config_data': {'$ref': '#/components/schemas/EngineConfig-Input', 'description': 'configuration data'}, 'config_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Config Id', 'description': 'ID of the configuration to fetch, or None for the currently active one'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Retrieve the active or historical config for an endpoint.\n\nTODO: This route should be renamed to /api/getConfig or similar.\n\nIf a config ID is provided in the request, that historical config is\nreturned.  The ID can be obtained from /api/getConfigHistory.   If no config\nID is provided, the currently active config is returned.\n\nThis will fetch the configuration from the database and potentially update\nit, if it uses an outdated version of the configuration data model.  If the\nconfiguration is invalid, it will still be returned with an extra field\n`validation_error` containing the validation error message.\n\nArgs:\n    request:\n        Data containing the endpoint name and config ID (if  historical).\n    userauth:\n        User authorization object to check permissions.\nReturns:\n    A response containing a LenientConfig object, in which `id` is the ID of\n    the configuration, `name` is a timestamp string of when the\n    configuration was created, and `engine_data` contains the configuration\n    data.\nRaises:\n    NonExistentEndpointError: (404)\n        If the endpoint does not exist.\n    InvalidInput: (200+success=false)\n        If the configuration ID is invalid.\n    NoSuccess: (200+success=false)\n        If the configuration could not be retrieved.\n    PermissionError: (403)\n        If the user does not have permission to view the config.')
# ToolDefinition(name='validate_config_api_validateConfig_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'config_data': {'$ref': '#/components/schemas/EngineConfig-Input', 'description': 'configuration data'}, 'config_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Config Id', 'description': 'ID of the configuration to fetch, or None for the currently active one'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Validate config for active endpoint of user.\n\nTODO: Review if this route is actually used and necessary.\n\nThis checks if the endpoint configuration data is valid using the Pydantic ConfigData model.\nIt also checks if the selected AI model is enabled.\n\nReturns:\n    A response indicating whether the configuration is valid or not.\n    If the configuration is invalid, an error message is returned.')
# ToolDefinition(name='set_config_api_setConfig_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'config_data': {'$ref': '#/components/schemas/EngineConfig-Input', 'description': 'configuration data'}, 'config_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Config Id', 'description': 'ID of the configuration to fetch, or None for the currently active one'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Set the configuration for the given endpoint.\n\nArgs:\n    request: Data containing the endpoint name and new configuration data.\n    userauth: User authorization object to check permissions.\nReturns:\n    A response containing the ID of the newly set configuration.\nRaises:\n    NonExistentEndpointError: (404)\n        If the endpoint does not exist.\n    InvalidInput: (200+success=false)\n        If the selected model is not available.')
# ToolDefinition(name='get_config_history_api_getConfigHistory_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'config_data': {'$ref': '#/components/schemas/EngineConfig-Input', 'description': 'configuration data'}, 'config_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Config Id', 'description': 'ID of the configuration to fetch, or None for the currently active one'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Get config history for active endpoint of user. Only names and ids are returned.\n\nReturns:\n    A response containing the list of configuration history items for the specified endpoint.')
# ToolDefinition(name='create_endpoint_api_createEndpoint_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'endpoint_attributes': {'anyOf': [{'$ref': '#/components/schemas/EndpointAttributes'}, {'type': 'null'}], 'description': 'Attributes of the endpoint'}, 'endpoint_metadata': {'anyOf': [{'$ref': '#/components/schemas/EndpointMetadata'}, {'type': 'null'}], 'description': 'Metadata of the endpoint'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Create a new endpoint\n\nThis will create a new endpoint with the given attributes and metadata.\n\nThe endpoint name must not already exist and needs to begin with a valid\nscope prefix.\n\nArgs:\n    request: Data containing the endpoint name, attributes, and metadata.\n    userauth: User authorization object to check permissions.\nReturns:\n    Response indicating success or failure.\nRaises:\n    InvalidInput: If the endpoint name is not valid or the model is not available.')
# ToolDefinition(name='get_endpoint_metadata_api_getEndpointMetadata_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Endpoint to get metadata for'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Get metadata for an endpoint.\n\nReturns:\n    A response containing the metadata for the specified endpoint.')
# ToolDefinition(name='update_endpoint_metadata_api_updateEndpointMetadata_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Endpoint to get metadata for'}, 'metadata': {'$ref': '#/components/schemas/EndpointMetadata', 'description': 'Metadata to update'}}, 'required': ['endpoint', 'metadata'], 'additionalProperties': False}, description='Update metadata for an endpoint.\n\nReturns:\n    A response indicating the success or failure of the operation.')
# ToolDefinition(name='delete_endpoint_api_deleteEndpoint_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Delete an existing endpoint\n\nThis will delete an existing endpoint and all data associated with it.\nThe endpoint must exist and the user must have permission to delete it.\n\nArgs:\n    endpoint_data: Data containing the endpoint name.\n    userauth: User authorization object to check permissions.\nReturns:\n    Response indicating success or failure.\nRaises:\n    InvalidInput: If the endpoint does not exist.')
# ToolDefinition(name='get_endpoints_api_getEndpoints_post', parameters_json_schema={'type': 'object', 'properties': {'prefix': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Prefix', 'description': 'Prefix of the endpoints to list'}}, 'required': [], 'additionalProperties': False}, description='List endpoints for the given name prefix.\n\nThis will return a list of endpoints with the given scope prefix that the\nuser has permission to view.  If scope is "/", it will list the endpoints\nfor all scopes.\n\nArgs:\n    request: Request containing the prefix to filter endpoints.\n    userauth: User authorization object to check permissions.\nReturns:\n    Response containing a list of endpoint suffixes and their metadata.')
# ToolDefinition(name='get_endpoint_authorization_api_endpoint_authorization_get', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'description': ''}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Retrieve the authorization configuration for an endpoint.\n\nArgs:\n    endpoint: The endpoint name.\n    userauth: User authorization object to check permissions.\nReturns:\n    The authorization configuration for the specified endpoint.')
# ToolDefinition(name='update_endpoint_authorization_api_endpoint_authorization_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'description': ''}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Update the authorization configuration for an endpoint.\n\nArgs:\n    endpoint: The endpoint name.\n    auth_config: New authorization configuration to set for the endpoint.\n    userauth: User authorization object to check permissions.')
# ToolDefinition(name='delete_endpoint_authorization_api_endpoint_authorization_delete', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'description': ''}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Delete the authorization configuration for an endpoint.\n\nEndpoint will revert to default authorization configuration.\n\nArgs:\n    endpoint: The endpoint name.\n    userauth: User authorization object to check permissions.')
# ToolDefinition(name='execute_evaluation_suite_api_executeEvaluationSuite_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}}, 'required': ['endpoint', 'test_suite_name'], 'additionalProperties': False}, description='Execute evaluations on the test suites\n\nReturns:\n    A response containing the evaluation results.\nRaises:\n    NoSuccess: If the test suite does not exist or the endpoint is invalid.')
# ToolDefinition(name='get_stored_evaluation_results_api_getStoredEvaluationResults_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}}, 'required': ['endpoint', 'test_suite_name'], 'additionalProperties': False}, description='Get evaluation results for a test suite.\n\nReturns:\n    A response containing the evaluation results.\nRaises:\n    NoSuccess: If the test suite does not exist or the endpoint is invalid.')
# ToolDefinition(name='get_evaluation_suites_api_getEvaluationSuites_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}}, 'required': ['endpoint'], 'additionalProperties': False}, description='Get list of names of evaluation suites from AWS.\n\nReturns:\n    A response containing the list of evaluation suite names.')
# ToolDefinition(name='get_evaluation_suite_by_name_api_getEvaluationSuiteContentsByName_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}}, 'required': ['endpoint', 'test_suite_name'], 'additionalProperties': False}, description='Get contents of evaluation suite by name from AWS.\n\nReturns:\n    A response containing the stored test suite.\nRaises:\n    NoSuccess: If the test suite does not exist.')
# ToolDefinition(name='get_evaluation_suite_history_by_name_api_getEvaluationSuiteHistoryByName_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}}, 'required': ['endpoint', 'test_suite_name'], 'additionalProperties': False}, description='Get history (previous versions) of evaluation suite by name from AWS.\n\nReturns:\n    A response containing the list of previous versions of the evaluation suite.\nRaises:\n    NoSuccess: If the test suite does not exist.')
# ToolDefinition(name='create_evaluation_suite_api_createEvaluationSuite_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}}, 'required': ['endpoint', 'test_suite_name'], 'additionalProperties': False}, description='Create a new evaluation suite in AWS.\n\nReturns:\n    A response indicating the success or failure of the operation.\nRaises:\n    NoSuccess: If the test suite name already exists.\n    ValueError: If the test suite name is invalid.')
# ToolDefinition(name='add_test_cases_to_evaluation_suite_api_addTestCasesToEvaluationSuite_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}, 'test_cases': {'items': {'$ref': '#/components/schemas/DialogTestCase'}, 'type': 'array', 'title': 'Test Cases', 'description': 'List of test cases to add or update'}}, 'required': ['endpoint', 'test_suite_name', 'test_cases'], 'additionalProperties': False}, description='Add test cases to an evaluation suite in AWS.\n\nReturns:\n    A response indicating the success or failure of the operation.\nRaises:\n    NoSuccess: If the test suite does not exist.')
# ToolDefinition(name='save_evaluation_suite_api_saveEvaluationSuite_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'test_suite_name': {'type': 'string', 'title': 'Test Suite Name', 'description': 'Name of test suite for the evaluation'}, 'test_cases': {'items': {'$ref': '#/components/schemas/DialogTestCase'}, 'type': 'array', 'title': 'Test Cases', 'description': 'List of test cases to add or update'}}, 'required': ['endpoint', 'test_suite_name', 'test_cases'], 'additionalProperties': False}, description='Change an evaluation suite in AWS.\n\nReturns:\n    A response indicating the success or failure of the operation.\nRaises:\n    NoSuccess: If the test suite does not exist.')
# ToolDefinition(name='get_cost_graph_snapshot_api_getCostGraphSnapshot_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'month': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'title': 'Month', 'description': 'Month for the data'}, 'unit': {'type': 'string', 'title': 'Unit', 'description': 'Unit of measurement (e.g., tokens or euro)'}}, 'required': ['endpoint', 'unit'], 'additionalProperties': False}, description='Get a snapshot of the token usage (for one week) for an endpoint.\n\nReturns:\n    A response containing a base64 encoded string of the graph image.')
# ToolDefinition(name='get_cost_per_day_api_getCostPerDay_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'month': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'title': 'Month', 'description': 'Month for the data'}, 'unit': {'type': 'string', 'title': 'Unit', 'description': 'Unit of measurement (e.g., tokens or euro)'}}, 'required': ['endpoint', 'unit'], 'additionalProperties': False}, description='Get token usage per day for an endpoint.\n\nReturns:\n    A dict with the date as key and the token usage as value.\nRaises:\n    InvalidInput: If the unit is not supported.')
# ToolDefinition(name='get_permissions_api__resource_type__permissions_get', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'description': 'Name of the resource'}}, 'required': ['resource_type', 'resource_name'], 'additionalProperties': False}, description='Get all the permissions for a resource.\n\nThis API returns a list of roles for the resource, each with a list of users\nand permissions. This includes the user-manageable permissions only.\n\nIn case the resource does not have any permissions, the API returns a\n404 error.\n\nReturns:\n    - success: True if the API call was successful\n    - data: list of roles for the resource, each with a list of users and permissions')
# ToolDefinition(name='add_role_api__resource_type__role_post', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}}, 'required': ['resource_type', 'resource_name', 'role'], 'additionalProperties': False}, description='Add a role to a resource.\n\nThis API adds a new role to an resource, with no users or permissions.\n\nIf a role by that name already exists, the API returns an error.\n\nRaises:\n    HTTPException: 422 if the role already exists')
# ToolDefinition(name='remove_role_api__resource_type__role_delete', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}}, 'required': ['resource_type', 'resource_name', 'role'], 'additionalProperties': False}, description='Remove a role from an resource.\n\nThis API removes a role from an resource. The owner role cannot be removed.\n\nRaises:\n    HTTPException: 422 if the role is the owner role')
# ToolDefinition(name='grant_permission_api__resource_type__role_permission_post', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'permission': {'type': 'string', 'title': 'Permission', 'description': 'ID of the permission to add or remove'}}, 'required': ['resource_type', 'resource_name', 'role', 'permission'], 'additionalProperties': False}, description='Grant a permission to a role.\n\nThis API grants a permission to a role on a resource.\n\nRaises:\n    HTTPException: 422 if the permission is already granted to the role')
# ToolDefinition(name='revoke_permission_api__resource_type__role_permission_delete', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'permission': {'type': 'string', 'title': 'Permission', 'description': 'ID of the permission to add or remove'}}, 'required': ['resource_type', 'resource_name', 'role', 'permission'], 'additionalProperties': False}, description='Revoke a permission from a role.\n\nThis API revokes a permission from a role on a resource.\n\nRaises:\n    HTTPException: 422 if the permission is not granted to the role')
# ToolDefinition(name='add_user_api__resource_type__role_user_post', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'user': {'type': 'string', 'title': 'User', 'description': 'Username of the user'}}, 'required': ['resource_type', 'resource_name', 'role', 'user'], 'additionalProperties': False}, description='Add a user to a role.\n\nThis API adds a user to a role on a resource.\n\nRaises:\n    HTTPException: 422 if the user is already a member of the role')
# ToolDefinition(name='remove_user_api__resource_type__role_user_delete', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'user': {'type': 'string', 'title': 'User', 'description': 'Username of the user'}}, 'required': ['resource_type', 'resource_name', 'role', 'user'], 'additionalProperties': False}, description='Remove a user from a role.\n\nThis API removes a user from a role on an resource.\nUser cannot remove themselves from the owner role.\n\nRaises:\n    HTTPException: 422 if the user is not a member of the role')
# ToolDefinition(name='get_ratings_aws_api_getRatingsAWS_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Endpoint'}, 'start': {'anyOf': [{'type': 'string', 'format': 'date-time'}, {'type': 'null'}], 'title': 'Start'}, 'end': {'anyOf': [{'type': 'string', 'format': 'date-time'}, {'type': 'null'}], 'title': 'End'}}, 'required': [], 'additionalProperties': False}, description='Get ratings from AWS DynamoDB.\n\nReturns:\n    A list of ratings.\nRaises:\n    NoSuccess: If there is an error retrieving ratings.')
# ToolDefinition(name='get_session_histories_api_getSessionHistories_post', parameters_json_schema={'type': 'object', 'properties': {'endpoint': {'type': 'string', 'title': 'Endpoint', 'description': 'Name of the endpoint'}, 'start_time': {'type': 'string', 'title': 'Start Time', 'description': 'Start time of the session'}, 'end_time': {'type': 'string', 'title': 'End Time', 'description': 'End time of the session'}}, 'required': ['endpoint', 'start_time', 'end_time'], 'additionalProperties': False}, description='Get session histories for endpoint\n\nArgs:\n    session_data: Data containing the endpoint name, start time, and end time.\n    userauth: User authorization object to check permissions.\nReturns:\n    Response containing a list of Conversation objects representing the session histories.')
# ToolDefinition(name='get_available_AI_models_api_getAvailableAIModels_post', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Get the available AI models from the model registry.\n\nThese are the models that can be used in endpoint configurations.\n\nReturns:\n    A response containing a list of available AI models.')
# ToolDefinition(name='get_scopes_api_getScopes_post', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Get all scopes available to user\n\nReturns:\n    A response containing a list of available scopes.')
# ToolDefinition(name='upload_file_to_S3_api_uploadToS3_post', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Upload file to S3 and return URI.\n\nTODO: Review if this route is actually used and necessary.\n\nReturns:\n    A response containing the URI of the uploaded file.')

# %%
## Step 2: Organize Tools into Groups

# Organize tools by functionality
tool_groups = {
    "endpoints": [],
    "configs": [],
    "evaluations": [],
    "permissions": [],
    "audit": [],
    "costs": [],
    "inventory": [],
    "other": []
}

# Define specific tool name mappings for new groups
audit_tools = [
    "get_aws_logs_api_getAWSLogs_post",
    "get_session_histories_api_getSessionHistories_post", 
    "get_ratings_aws_api_getRatingsAWS_post"
]

cost_tools = [
    "get_cost_graph_snapshot_api_getCostGraphSnapshot_post",
    "get_cost_per_day_api_getCostPerDay_post"
]

inventory_tools = [
    "get_capabilities_api_capabilities_get",
    "get_available_AI_models_api_getAvailableAIModels_post",
    "get_scopes_api_getScopes_post"
]

for tool in tools:
    name_lower = tool.name.lower()
    
    # Check specific tool mappings first
    if tool.name in audit_tools:
        tool_groups["audit"].append(tool)
    elif tool.name in cost_tools:
        tool_groups["costs"].append(tool)
    elif tool.name in inventory_tools:
        tool_groups["inventory"].append(tool)
    # Then check general patterns
    elif 'endpoint' in name_lower:
        tool_groups["endpoints"].append(tool)
    elif 'config' in name_lower:
        tool_groups["configs"].append(tool)
    elif 'evaluation' in name_lower or 'suite' in name_lower:
        tool_groups["evaluations"].append(tool)
    elif 'permission' in name_lower or 'role' in name_lower:
        tool_groups["permissions"].append(tool)
    else:
        tool_groups["other"].append(tool)

# Display the groups and their tools
print("\n📊 Tool Groups Summary:\n")
for group_name, group_tools in tool_groups.items():
    print(f"{group_name.upper()}: {len(group_tools)} tools")
    for tool in group_tools:
        print(f"  • {tool.name}")
    print()
# Out:
# 📊 Tool Groups Summary:
#
# ENDPOINTS: 8 tools
#   • create_endpoint_api_createEndpoint_post
#   • get_endpoint_metadata_api_getEndpointMetadata_post
#   • update_endpoint_metadata_api_updateEndpointMetadata_post
#   • delete_endpoint_api_deleteEndpoint_post
#   • get_endpoints_api_getEndpoints_post
#   • get_endpoint_authorization_api_endpoint_authorization_get
#   • update_endpoint_authorization_api_endpoint_authorization_post
#   • delete_endpoint_authorization_api_endpoint_authorization_delete
#
# CONFIGS: 4 tools
#   • get_active_config_api_getActiveConfig_post
#   • validate_config_api_validateConfig_post
#   • set_config_api_setConfig_post
#   • get_config_history_api_getConfigHistory_post
#
# EVALUATIONS: 8 tools
#   • execute_evaluation_suite_api_executeEvaluationSuite_post
#   • get_stored_evaluation_results_api_getStoredEvaluationResults_post
#   • get_evaluation_suites_api_getEvaluationSuites_post
#   • get_evaluation_suite_by_name_api_getEvaluationSuiteContentsByName_post
#   • get_evaluation_suite_history_by_name_api_getEvaluationSuiteHistoryByName_post
#   • create_evaluation_suite_api_createEvaluationSuite_post
#   • add_test_cases_to_evaluation_suite_api_addTestCasesToEvaluationSuite_post
#   • save_evaluation_suite_api_saveEvaluationSuite_post
#
# PERMISSIONS: 7 tools
#   • get_permissions_api__resource_type__permissions_get
#   • add_role_api__resource_type__role_post
#   • remove_role_api__resource_type__role_delete
#   • grant_permission_api__resource_type__role_permission_post
#   • revoke_permission_api__resource_type__role_permission_delete
#   • add_user_api__resource_type__role_user_post
#   • remove_user_api__resource_type__role_user_delete
#
# AUDIT: 3 tools
#   • get_aws_logs_api_getAWSLogs_post
#   • get_ratings_aws_api_getRatingsAWS_post
#   • get_session_histories_api_getSessionHistories_post
#
# COSTS: 2 tools
#   • get_cost_graph_snapshot_api_getCostGraphSnapshot_post
#   • get_cost_per_day_api_getCostPerDay_post
#
# INVENTORY: 3 tools
#   • get_capabilities_api_capabilities_get
#   • get_available_AI_models_api_getAvailableAIModels_post
#   • get_scopes_api_getScopes_post
#
# OTHER: 1 tools
#   • upload_file_to_S3_api_uploadToS3_post
