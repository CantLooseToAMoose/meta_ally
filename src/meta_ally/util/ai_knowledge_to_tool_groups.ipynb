# %% [markdown]
# # AI Knowledge API to Pydantic-AI Tools - Complete Demo
#
# This notebook demonstrates the complete workflow for converting the AI Knowledge API OpenAPI specifications into pydantic-ai tools and organizing them into logical groups.

# %%
# Step 1: Load the AI Knowledge API OpenAPI Tools

import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

from lib.openapi_to_tools import OpenAPIToolsLoader

# Initialize the loader for AI Knowledge API
loader = OpenAPIToolsLoader(
    openapi_url="https://backend-api.dev.ai-knowledge.aws.inform-cloud.io/openapi.json",
    models_filename="ai_knowledge_api_models.py",
    regenerate_models=True  # Generate the models file
)

# Load all tools
print("Loading tools from AI Knowledge API OpenAPI spec...")
tools = loader.load_tools()

print(f"\n✅ Successfully loaded {len(tools)} tools!")
print(f"\nAll tools:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool.name}")
# Out:
# Loading tools from AI Knowledge API OpenAPI spec...
# Generating models file 'ai_knowledge_api_models.py' from https://backend-api.dev.ai-knowledge.aws.inform-cloud.io/openapi.json...
# Successfully generated 'ai_knowledge_api_models.py'
# Created tool: list_collections [GET /collections/]
# Created tool: create_collection [POST /collections/]
# Created tool: get_collection_configuration [GET /collections/{collection_id}]
# Created tool: update_collection [PUT /collections/{collection_id}]
# Created tool: delete_collection [DELETE /collections/{collection_id}]
# Created tool: index_collection [POST /collections/{collection_id}/index]
# Created tool: query [POST /collections/{collection_id}/query]
# Created tool: get_fragment_counts [GET /collections/{collection_id}/fragments/counts]
# Created tool: get_collection_usage [GET /collections/{collection_id}/usage]
# Created tool: list_sources [GET /sources/]
# Created tool: create_source [POST /sources/]
# Created tool: get_source_configuration [GET /sources/{source_id}]
# Created tool: update_source [PUT /sources/{source_id}]
# Created tool: delete_source [DELETE /sources/{source_id}]
# Created tool: health_check [GET /api/test]
# Created tool: check_connection_s3 [POST /connections/s3/test]
# Created tool: check_connection_github [POST /connections/github/test]
# Created tool: check_connection_website [POST /connections/website/test]
# Created tool: info [GET /info]
# Created tool: available_models [GET /models]
# Created tool: delete_document [DELETE /collections/{collection_id}/documents/{filename}]
# Created tool: get_presigned_url [POST /collections/{collection_id}/documents/{filename}]
# Created tool: get_documents_indexed [GET /collections/{collection_id}/documents/indexed]
# Created tool: get_document_uploaded [GET /collections/{collection_id}/documents/uploaded]
# Created tool: get_document_content [GET /collections/{collection_id}/documents/{document_id}/content]
# Created tool: get_document_fragments [GET /collections/{collection_id}/documents/{document_id}/fragments]
# Created tool: get_index_runs [GET /collections/{collection_id}/indexRuns]
# Created tool: get_index_run_tasks [GET /collections/{collection_id}/indexRuns/{index_run_id}]
# Created tool: get_index_run_progress [GET /collections/{collection_id}/indexRuns/{index_run_id}/progress]
# Created tool: get_index_run_token_usage [GET /collections/{collection_id}/indexRuns/{index_run_id}/tokenUsage]
# Created tool: get_permissions [GET /{resource_type}/permissions]
# Created tool: add_role [POST /{resource_type}/role]
# Created tool: remove_role [DELETE /{resource_type}/role]
# Created tool: grant_permission [POST /{resource_type}/role/permission]
# Created tool: revoke_permission [DELETE /{resource_type}/role/permission]
# Created tool: add_user [POST /{resource_type}/role/user]
# Created tool: remove_user [DELETE /{resource_type}/role/user]
#
# ✅ Successfully loaded 37 tools!
#
# All tools:
#   1. list_collections
#   2. create_collection
#   3. get_collection_configuration
#   4. update_collection
#   5. delete_collection
#   6. index_collection
#   7. query
#   8. get_fragment_counts
#   9. get_collection_usage
#   10. list_sources
#   11. create_source
#   12. get_source_configuration
#   13. update_source
#   14. delete_source
#   15. health_check
#   16. check_connection_s3
#   17. check_connection_github
#   18. check_connection_website
#   19. info
#   20. available_models
#   21. delete_document
#   22. get_presigned_url
#   23. get_documents_indexed
#   24. get_document_uploaded
#   25. get_document_content
#   26. get_document_fragments
#   27. get_index_runs
#   28. get_index_run_tasks
#   29. get_index_run_progress
#   30. get_index_run_token_usage
#   31. get_permissions
#   32. add_role
#   33. remove_role
#   34. grant_permission
#   35. revoke_permission
#   36. add_user
#   37. remove_user

# %%
# Check out Tool Definitions
print("🔍 Tool Definitions:\n")
for tool in tools:
    print(f"Tool: {tool.name}")
    print(f"Definition: {tool.tool_def}")
    print("-" * 80)
# Out:
# 🔍 Tool Definitions:
#
# Tool: list_collections
# Definition: ToolDefinition(name='list_collections', parameters_json_schema={'type': 'object', 'properties': {'lastIndexRun': {'type': 'string', 'description': 'Flag to return the last index run of each collection.'}, 'nextIndexRun': {'type': 'string', 'description': 'Flag to return the next scheduled index run of each collection.'}, 'collectionId': {'type': 'string', 'description': "Collection ID(s) to filter by. This is a 'contains' filter - supports multiple values with OR logic."}, 'description': {'type': 'string', 'description': "Description(s) to filter by. This is a 'contains' filter - supports multiple values with OR logic."}, 'public': {'type': 'string', 'description': 'Flag to filter by public collections.'}, 'accessDenied': {'type': 'string', 'description': 'Access denied flag(s) to filter by. Supports multiple values with OR logic.'}, 'businessDepartment': {'type': 'string', 'description': "Business department to filter by. This is a 'contains' filter."}, 'projectNumber': {'type': 'string', 'description': "Project number(s) to filter by. This is a 'contains' filter - supports multiple values with OR logic."}, 'limit': {'type': 'string', 'description': 'Limit the number of collections to return.', 'default': 1000}, 'nextToken': {'type': 'string', 'description': 'Token for pagination.'}}, 'required': [], 'additionalProperties': False}, description='List all collections sorted by collectionId.')
# --------------------------------------------------------------------------------
# Tool: create_collection
# Definition: ToolDefinition(name='create_collection', parameters_json_schema={'type': 'object', 'properties': {'collectionId': {'type': 'string', 'maxLength': 62, 'minLength': 8, 'pattern': '^[a-zA-Z_][a-zA-Z0-9_]*$', 'title': 'Collectionid', 'description': 'A unique identifier for the collection.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the collection.'}, 'projectNumber': {'type': 'string', 'pattern': '^(00000|[1-9]\\d{4}|1\\d{5})$', 'title': 'Projectnumber', 'description': 'Project number related to the collection. This number is used to derive the business department (GB) and to allocate costs. Note: Changes to this field take effect on cost allocation at the next day (00:00 UTC).', 'default': '00000'}, 'sources': {'items': {'type': 'string', 'maxLength': 255, 'minLength': 0, 'pattern': '^[a-zA-Z0-9-_]+$', 'description': 'A list of source identifiers associated with the collection.'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Sources', 'description': 'A list of source identifiers associated with the collection.'}, 'metadata': {'additionalProperties': True, 'type': 'object', 'title': 'Metadata', 'description': 'Additional metadata for the collection.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the collection is publicly accessible.', 'default': False}, 'collectionType': {'oneOf': [{'properties': {'databaseType': {'type': 'string', 'title': 'Databasetype', 'default': 'postgresql-pgvector', 'enum': ['postgresql-pgvector']}, 'vectorType': {'type': 'string', 'enum': ['vector', 'halfvec', 'bit', 'sparsevec'], 'title': 'Vectortype', 'description': "The type of vector representation to use. One of:\n- 'vector': Single-precision dense vector (float32). Highest numeric fidelity (~4 bytes per dimension), compatible with most libraries, and recommended for training and high-accuracy similarity search.\n- 'halfvec': Half-precision dense vector (float16). Reduces memory and I/O (~2 bytes per dimension) at the cost of lower precision; suitable when memory bandwidth or storage is a bottleneck and slight accuracy loss is acceptable.\n- 'bit': Binary vector (bit-packed 0/1 or sign bits). Extremely compact and fast for large-scale retrieval using Hamming distance or bitwise ops. Typically derived via hashing or sign quantization; best for approximate similarity at very large index sizes.\n- 'sparsevec': Sparse vector storing only non-zero entries (e.g., as {index: value} or a list of (index, value) pairs). Efficient for very high-dimensional, mostly-zero features (e.g., bag-of-words), and commonly used with cosine or inner-product over sparse structures.", 'default': 'vector'}}, 'type': 'object', 'title': 'VectorDBPostgreSQL', 'description': 'Configuration for PostgreSQL vector database.'}, {'properties': {'databaseType': {'type': 'string', 'title': 'Databasetype', 'default': 's3-vector-bucket', 'enum': ['s3-vector-bucket']}}, 'type': 'object', 'title': 'S3VectorBucket', 'description': 'Configuration for S3 vector bucket.'}], 'title': 'Collectiontype', 'description': 'The type of the collection. This defines which vector database is used and how it is configured.', 'discriminator': {'propertyName': 'databaseType', 'mapping': {'postgresql-pgvector': '#/components/schemas/VectorDBPostgreSQL', 's3-vector-bucket': '#/components/schemas/S3VectorBucket'}}}, 'plugins': {'items': {'oneOf': [{'properties': {'pluginScope': {'type': 'string', 'title': 'Pluginscope', 'default': 'document', 'enum': ['document']}, 'pluginType': {'type': 'string', 'title': 'Plugintype', 'default': 'document_summary', 'enum': ['document_summary']}, 'pluginName': {'type': 'string', 'title': 'Pluginname', 'description': 'A unique name to identify the plugin instance by.'}, 'allowFailure': {'type': 'boolean', 'title': 'Allowfailure', 'description': 'Flag whether a failure of a plugin should mark processing as failed. Currently this flag is  ...
# --------------------------------------------------------------------------------
# Tool: get_collection_configuration
# Definition: ToolDefinition(name='get_collection_configuration', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}}, 'required': ['collection_id'], 'additionalProperties': False}, description='Get the configuration for the specified collection.')
# --------------------------------------------------------------------------------
# Tool: update_collection
# Definition: ToolDefinition(name='update_collection', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'collectionId': {'type': 'string', 'maxLength': 62, 'minLength': 8, 'pattern': '^[a-zA-Z_][a-zA-Z0-9_]*$', 'title': 'Collectionid', 'description': 'A unique identifier for the collection.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the collection.'}, 'projectNumber': {'type': 'string', 'pattern': '^(00000|[1-9]\\d{4}|1\\d{5})$', 'title': 'Projectnumber', 'description': 'Project number related to the collection. This number is used to derive the business department (GB) and to allocate costs. Note: Changes to this field take effect on cost allocation at the next day (00:00 UTC).', 'default': '00000'}, 'sources': {'items': {'type': 'string', 'maxLength': 255, 'minLength': 0, 'pattern': '^[a-zA-Z0-9-_]+$', 'description': 'A list of source identifiers associated with the collection.'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Sources', 'description': 'A list of source identifiers associated with the collection.'}, 'metadata': {'additionalProperties': True, 'type': 'object', 'title': 'Metadata', 'description': 'Additional metadata for the collection.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the collection is publicly accessible.', 'default': False}, 'collectionType': {'oneOf': [{'properties': {'databaseType': {'type': 'string', 'title': 'Databasetype', 'default': 'postgresql-pgvector', 'enum': ['postgresql-pgvector']}, 'vectorType': {'type': 'string', 'enum': ['vector', 'halfvec', 'bit', 'sparsevec'], 'title': 'Vectortype', 'description': "The type of vector representation to use. One of:\n- 'vector': Single-precision dense vector (float32). Highest numeric fidelity (~4 bytes per dimension), compatible with most libraries, and recommended for training and high-accuracy similarity search.\n- 'halfvec': Half-precision dense vector (float16). Reduces memory and I/O (~2 bytes per dimension) at the cost of lower precision; suitable when memory bandwidth or storage is a bottleneck and slight accuracy loss is acceptable.\n- 'bit': Binary vector (bit-packed 0/1 or sign bits). Extremely compact and fast for large-scale retrieval using Hamming distance or bitwise ops. Typically derived via hashing or sign quantization; best for approximate similarity at very large index sizes.\n- 'sparsevec': Sparse vector storing only non-zero entries (e.g., as {index: value} or a list of (index, value) pairs). Efficient for very high-dimensional, mostly-zero features (e.g., bag-of-words), and commonly used with cosine or inner-product over sparse structures.", 'default': 'vector'}}, 'type': 'object', 'title': 'VectorDBPostgreSQL', 'description': 'Configuration for PostgreSQL vector database.'}, {'properties': {'databaseType': {'type': 'string', 'title': 'Databasetype', 'default': 's3-vector-bucket', 'enum': ['s3-vector-bucket']}}, 'type': 'object', 'title': 'S3VectorBucket', 'description': 'Configuration for S3 vector bucket.'}], 'title': 'Collectiontype', 'description': 'The type of the collection. This defines which vector database is used and how it is configured.', 'discriminator': {'propertyName': 'databaseType', 'mapping': {'postgresql-pgvector': '#/components/schemas/VectorDBPostgreSQL', 's3-vector-bucket': '#/components/schemas/S3VectorBucket'}}}, 'plugins': {'items': {'oneOf': [{'properties': {'pluginScope': {'type': 'string', 'title': 'Pluginscope', 'default': 'document', 'enum': ['document']}, 'pluginType': {'type': 'string', 'title': 'Plugintype', 'default': 'document_summary', 'enum': ['document_summary']}, 'pluginName': {'type': 'string', 'title': 'Pluginname', 'description': 'A unique name to identify the plugin instance by.'}, 'allowFailure': {'type': 'boolean', 'title': 'Allowfailure', 'description': 'Flag whether a failure of a plugin s ...
# --------------------------------------------------------------------------------
# Tool: delete_collection
# Definition: ToolDefinition(name='delete_collection', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}}, 'required': ['collection_id'], 'additionalProperties': False}, description='Delete a collection.')
# --------------------------------------------------------------------------------
# Tool: index_collection
# Definition: ToolDefinition(name='index_collection', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'forceRun': {'type': 'boolean', 'description': 'Force the indexing run to rerun on all documents.', 'default': False}}, 'required': ['collection_id'], 'additionalProperties': False}, description='Trigger an index run for a collection.')
# --------------------------------------------------------------------------------
# Tool: query
# Definition: ToolDefinition(name='query', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'limit': {'type': 'integer', 'description': 'Maximum number of results to return.', 'default': 5}, 'metric': {'type': 'string', 'description': 'Similarity metric to use for the vector search.', 'enum': ['L2 distance', '(negative) inner product', 'cosine distance', 'L1 distance', 'Hamming distance', 'Jaccard distance'], 'default': 'cosine distance'}, 'documentNameContains': {'type': 'string', 'description': 'Filter for documents whose names contain any of the provided strings (case-insensitive).'}, 'text': {'type': 'string', 'title': 'Text', 'description': 'Text to query against the collection.'}}, 'required': ['collection_id', 'text'], 'additionalProperties': False}, description='Query a collection.')
# --------------------------------------------------------------------------------
# Tool: get_fragment_counts
# Definition: ToolDefinition(name='get_fragment_counts', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}}, 'required': ['collection_id'], 'additionalProperties': False}, description='Get information about the number of fragments in a collection.')
# --------------------------------------------------------------------------------
# Tool: get_collection_usage
# Definition: ToolDefinition(name='get_collection_usage', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'startDate': {'type': 'string', 'description': 'Start date for the usage data. If not provided, return data from the earliest date. The date is inclusive'}, 'endDate': {'type': 'string', 'description': 'End date for the usage data. If not provided, return data up to the latest available date. The date is inclusive.'}}, 'required': ['collection_id'], 'additionalProperties': False}, description='Get information about the usage of a collection.')
# --------------------------------------------------------------------------------
# Tool: list_sources
# Definition: ToolDefinition(name='list_sources', parameters_json_schema={'type': 'object', 'properties': {'sourceId': {'type': 'string', 'description': "Source ID(s) to filter by. This is a 'contains' filter - supports multiple values with OR logic."}, 'description': {'type': 'string', 'description': "Description(s) to filter by. This is a 'contains' filter - supports multiple values with OR logic."}, 'sourceType': {'type': 'string', 'description': 'Source type(s) to filter by. Supports multiple values with OR logic.'}, 'accessDenied': {'type': 'string', 'description': 'Flag(s) indicating if access to the source is denied. Supports multiple values with OR logic. Default is None showing all sources'}, 'limit': {'type': 'string', 'description': 'Limit the number of sources to return.', 'default': 1000}, 'nextToken': {'type': 'string', 'description': 'Token for pagination.'}}, 'required': [], 'additionalProperties': False}, description='List all sources sorted by sourceId.')
# --------------------------------------------------------------------------------
# Tool: create_source
# Definition: ToolDefinition(name='create_source', parameters_json_schema={'type': 'object', 'properties': {'sourceId': {'type': 'string', 'maxLength': 255, 'minLength': 8, 'pattern': '^[a-zA-Z0-9-_]+$', 'title': 'Sourceid', 'description': 'A unique identifier for the data source.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the data source.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the source is publicly accessible.', 'default': False}, 'properties': {'oneOf': [{'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description': 'A list of suffixes to filter objects in the source.', 'default': []}, 'prefixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefixignore', 'description': 'A list of prefixes to filter objects in the source to be ignored.', 'default': []}, 'suffixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffixignore', 'description': 'A list of suffixes to filter objects in the source to be ignored.', 'default': []}, 'sourceType': {'type': 'string', 'title': 'Sourcetype', 'description': "The type of the source, which is 'website' for this model.", 'default': 'website', 'enum': ['website']}, 'urls': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 1, 'title': 'Urls', 'description': 'A list of URLs of the websites to extract information from.'}, 'includeSitemap': {'type': 'boolean', 'title': 'Includesitemap', 'description': 'Set this to true to search for the sitemap of a url and extract information from all urls in the sitemap.', 'default': False}, 'authentication': {'anyOf': [{'oneOf': [{'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Basic', 'enum': ['Basic']}, 'username': {'type': 'string', 'title': 'Username', 'description': 'Username for basic authentication.'}, 'password': {'type': 'string', 'format': 'password', 'title': 'Password', 'description': 'Password for basic authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['username', 'password'], 'title': 'BasicAuthentication', 'description': 'Basic authentication configuration for website sources.'}, {'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Bearer', 'enum': ['Bearer']}, 'token': {'type': 'string', 'format': 'password', 'title': 'Token', 'description': 'Bearer token for authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['token'], 'title': 'BearerAuthentication', 'description': 'Bearer authentication configuration for website sources.'}], 'discriminator': {'propertyName': 'authenticationScheme', 'mapping': {'Basic': '#/components/schemas/BasicAuthentication', 'Bearer': '#/components/schemas/BearerAuthentication'}}}, {'type': 'null'}], 'title': 'Authentication', 'description': 'Authentication configuration for accessing the website.'}}, 'additionalProperties': False, 'type': 'object', 'required': ['urls'], 'title': 'WebsiteSourceProperties', 'description': 'Properties specific to website sources.'}, {'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description ...
# --------------------------------------------------------------------------------
# Tool: get_source_configuration
# Definition: ToolDefinition(name='get_source_configuration', parameters_json_schema={'type': 'object', 'properties': {'source_id': {'type': 'string', 'description': ''}}, 'required': ['source_id'], 'additionalProperties': False}, description='Get the configuration for the specified source.')
# --------------------------------------------------------------------------------
# Tool: update_source
# Definition: ToolDefinition(name='update_source', parameters_json_schema={'type': 'object', 'properties': {'source_id': {'type': 'string', 'description': ''}, 'sourceId': {'type': 'string', 'maxLength': 255, 'minLength': 8, 'pattern': '^[a-zA-Z0-9-_]+$', 'title': 'Sourceid', 'description': 'A unique identifier for the data source.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the data source.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the source is publicly accessible.', 'default': False}, 'properties': {'oneOf': [{'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description': 'A list of suffixes to filter objects in the source.', 'default': []}, 'prefixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefixignore', 'description': 'A list of prefixes to filter objects in the source to be ignored.', 'default': []}, 'suffixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffixignore', 'description': 'A list of suffixes to filter objects in the source to be ignored.', 'default': []}, 'sourceType': {'type': 'string', 'title': 'Sourcetype', 'description': "The type of the source, which is 'website' for this model.", 'default': 'website', 'enum': ['website']}, 'urls': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 1, 'title': 'Urls', 'description': 'A list of URLs of the websites to extract information from.'}, 'includeSitemap': {'type': 'boolean', 'title': 'Includesitemap', 'description': 'Set this to true to search for the sitemap of a url and extract information from all urls in the sitemap.', 'default': False}, 'authentication': {'anyOf': [{'oneOf': [{'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Basic', 'enum': ['Basic']}, 'username': {'type': 'string', 'title': 'Username', 'description': 'Username for basic authentication.'}, 'password': {'type': 'string', 'format': 'password', 'title': 'Password', 'description': 'Password for basic authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['username', 'password'], 'title': 'BasicAuthentication', 'description': 'Basic authentication configuration for website sources.'}, {'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Bearer', 'enum': ['Bearer']}, 'token': {'type': 'string', 'format': 'password', 'title': 'Token', 'description': 'Bearer token for authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['token'], 'title': 'BearerAuthentication', 'description': 'Bearer authentication configuration for website sources.'}], 'discriminator': {'propertyName': 'authenticationScheme', 'mapping': {'Basic': '#/components/schemas/BasicAuthentication', 'Bearer': '#/components/schemas/BearerAuthentication'}}}, {'type': 'null'}], 'title': 'Authentication', 'description': 'Authentication configuration for accessing the website.'}}, 'additionalProperties': False, 'type': 'object', 'required': ['urls'], 'title': 'WebsiteSourceProperties', 'description': 'Properties specific to website sources.'}, {'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems' ...
# --------------------------------------------------------------------------------
# Tool: delete_source
# Definition: ToolDefinition(name='delete_source', parameters_json_schema={'type': 'object', 'properties': {'source_id': {'type': 'string', 'description': ''}}, 'required': ['source_id'], 'additionalProperties': False}, description='Delete the configuration of a source.')
# --------------------------------------------------------------------------------
# Tool: health_check
# Definition: ToolDefinition(name='health_check', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Health check endpoint that always returns 200.')
# --------------------------------------------------------------------------------
# Tool: check_connection_s3
# Definition: ToolDefinition(name='check_connection_s3', parameters_json_schema={'type': 'object', 'properties': {'sourceId': {'type': 'string', 'maxLength': 255, 'minLength': 8, 'pattern': '^[a-zA-Z0-9-_]+$', 'title': 'Sourceid', 'description': 'A unique identifier for the data source.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the data source.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the source is publicly accessible.', 'default': False}, 'properties': {'oneOf': [{'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description': 'A list of suffixes to filter objects in the source.', 'default': []}, 'prefixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefixignore', 'description': 'A list of prefixes to filter objects in the source to be ignored.', 'default': []}, 'suffixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffixignore', 'description': 'A list of suffixes to filter objects in the source to be ignored.', 'default': []}, 'sourceType': {'type': 'string', 'title': 'Sourcetype', 'description': "The type of the source, which is 'website' for this model.", 'default': 'website', 'enum': ['website']}, 'urls': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 1, 'title': 'Urls', 'description': 'A list of URLs of the websites to extract information from.'}, 'includeSitemap': {'type': 'boolean', 'title': 'Includesitemap', 'description': 'Set this to true to search for the sitemap of a url and extract information from all urls in the sitemap.', 'default': False}, 'authentication': {'anyOf': [{'oneOf': [{'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Basic', 'enum': ['Basic']}, 'username': {'type': 'string', 'title': 'Username', 'description': 'Username for basic authentication.'}, 'password': {'type': 'string', 'format': 'password', 'title': 'Password', 'description': 'Password for basic authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['username', 'password'], 'title': 'BasicAuthentication', 'description': 'Basic authentication configuration for website sources.'}, {'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Bearer', 'enum': ['Bearer']}, 'token': {'type': 'string', 'format': 'password', 'title': 'Token', 'description': 'Bearer token for authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['token'], 'title': 'BearerAuthentication', 'description': 'Bearer authentication configuration for website sources.'}], 'discriminator': {'propertyName': 'authenticationScheme', 'mapping': {'Basic': '#/components/schemas/BasicAuthentication', 'Bearer': '#/components/schemas/BearerAuthentication'}}}, {'type': 'null'}], 'title': 'Authentication', 'description': 'Authentication configuration for accessing the website.'}}, 'additionalProperties': False, 'type': 'object', 'required': ['urls'], 'title': 'WebsiteSourceProperties', 'description': 'Properties specific to website sources.'}, {'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'descr ...
# --------------------------------------------------------------------------------
# Tool: check_connection_github
# Definition: ToolDefinition(name='check_connection_github', parameters_json_schema={'type': 'object', 'properties': {'sourceId': {'type': 'string', 'maxLength': 255, 'minLength': 8, 'pattern': '^[a-zA-Z0-9-_]+$', 'title': 'Sourceid', 'description': 'A unique identifier for the data source.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the data source.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the source is publicly accessible.', 'default': False}, 'properties': {'oneOf': [{'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description': 'A list of suffixes to filter objects in the source.', 'default': []}, 'prefixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefixignore', 'description': 'A list of prefixes to filter objects in the source to be ignored.', 'default': []}, 'suffixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffixignore', 'description': 'A list of suffixes to filter objects in the source to be ignored.', 'default': []}, 'sourceType': {'type': 'string', 'title': 'Sourcetype', 'description': "The type of the source, which is 'website' for this model.", 'default': 'website', 'enum': ['website']}, 'urls': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 1, 'title': 'Urls', 'description': 'A list of URLs of the websites to extract information from.'}, 'includeSitemap': {'type': 'boolean', 'title': 'Includesitemap', 'description': 'Set this to true to search for the sitemap of a url and extract information from all urls in the sitemap.', 'default': False}, 'authentication': {'anyOf': [{'oneOf': [{'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Basic', 'enum': ['Basic']}, 'username': {'type': 'string', 'title': 'Username', 'description': 'Username for basic authentication.'}, 'password': {'type': 'string', 'format': 'password', 'title': 'Password', 'description': 'Password for basic authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['username', 'password'], 'title': 'BasicAuthentication', 'description': 'Basic authentication configuration for website sources.'}, {'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Bearer', 'enum': ['Bearer']}, 'token': {'type': 'string', 'format': 'password', 'title': 'Token', 'description': 'Bearer token for authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['token'], 'title': 'BearerAuthentication', 'description': 'Bearer authentication configuration for website sources.'}], 'discriminator': {'propertyName': 'authenticationScheme', 'mapping': {'Basic': '#/components/schemas/BasicAuthentication', 'Bearer': '#/components/schemas/BearerAuthentication'}}}, {'type': 'null'}], 'title': 'Authentication', 'description': 'Authentication configuration for accessing the website.'}}, 'additionalProperties': False, 'type': 'object', 'required': ['urls'], 'title': 'WebsiteSourceProperties', 'description': 'Properties specific to website sources.'}, {'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'd ...
# --------------------------------------------------------------------------------
# Tool: check_connection_website
# Definition: ToolDefinition(name='check_connection_website', parameters_json_schema={'type': 'object', 'properties': {'sourceId': {'type': 'string', 'maxLength': 255, 'minLength': 8, 'pattern': '^[a-zA-Z0-9-_]+$', 'title': 'Sourceid', 'description': 'A unique identifier for the data source.'}, 'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Description', 'description': 'Description of the data source.'}, 'public': {'type': 'boolean', 'title': 'Public', 'description': 'Flag indicating if the source is publicly accessible.', 'default': False}, 'properties': {'oneOf': [{'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', 'description': 'A list of suffixes to filter objects in the source.', 'default': []}, 'prefixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefixignore', 'description': 'A list of prefixes to filter objects in the source to be ignored.', 'default': []}, 'suffixIgnore': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffixignore', 'description': 'A list of suffixes to filter objects in the source to be ignored.', 'default': []}, 'sourceType': {'type': 'string', 'title': 'Sourcetype', 'description': "The type of the source, which is 'website' for this model.", 'default': 'website', 'enum': ['website']}, 'urls': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 1, 'title': 'Urls', 'description': 'A list of URLs of the websites to extract information from.'}, 'includeSitemap': {'type': 'boolean', 'title': 'Includesitemap', 'description': 'Set this to true to search for the sitemap of a url and extract information from all urls in the sitemap.', 'default': False}, 'authentication': {'anyOf': [{'oneOf': [{'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Basic', 'enum': ['Basic']}, 'username': {'type': 'string', 'title': 'Username', 'description': 'Username for basic authentication.'}, 'password': {'type': 'string', 'format': 'password', 'title': 'Password', 'description': 'Password for basic authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['username', 'password'], 'title': 'BasicAuthentication', 'description': 'Basic authentication configuration for website sources.'}, {'properties': {'authenticationScheme': {'type': 'string', 'title': 'Authenticationscheme', 'description': 'The authentication scheme used for the website.', 'default': 'Bearer', 'enum': ['Bearer']}, 'token': {'type': 'string', 'format': 'password', 'title': 'Token', 'description': 'Bearer token for authentication.', 'writeOnly': True}}, 'additionalProperties': False, 'type': 'object', 'required': ['token'], 'title': 'BearerAuthentication', 'description': 'Bearer authentication configuration for website sources.'}], 'discriminator': {'propertyName': 'authenticationScheme', 'mapping': {'Basic': '#/components/schemas/BasicAuthentication', 'Bearer': '#/components/schemas/BearerAuthentication'}}}, {'type': 'null'}], 'title': 'Authentication', 'description': 'Authentication configuration for accessing the website.'}}, 'additionalProperties': False, 'type': 'object', 'required': ['urls'], 'title': 'WebsiteSourceProperties', 'description': 'Properties specific to website sources.'}, {'properties': {'prefix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Prefix', 'description': 'A list of prefixes to filter objects in the source.', 'default': []}, 'suffix': {'items': {'type': 'string'}, 'type': 'array', 'maxItems': 32, 'minItems': 0, 'title': 'Suffix', ' ...
# --------------------------------------------------------------------------------
# Tool: info
# Definition: ToolDefinition(name='info', parameters_json_schema={'type': 'object', 'properties': {}, 'required': [], 'additionalProperties': False}, description='Information about the API.')
# --------------------------------------------------------------------------------
# Tool: available_models
# Definition: ToolDefinition(name='available_models', parameters_json_schema={'type': 'object', 'properties': {'modelType': {'type': 'string', 'description': "Filter models by type (e.g., 'text-completion', 'text-embedding', 'multimodal-completion)."}, 'provider': {'type': 'string', 'description': "Filter models by provider (e.g., 'azure', 'openai', 'cohere', 'bedrock')."}}, 'required': [], 'additionalProperties': False}, description='Get available LLM and embedding models.')
# --------------------------------------------------------------------------------
# Tool: delete_document
# Definition: ToolDefinition(name='delete_document', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'filename': {'type': 'string', 'description': ''}}, 'required': ['collection_id', 'filename'], 'additionalProperties': False}, description='Delete a document from a collection, which was manually uploaded.')
# --------------------------------------------------------------------------------
# Tool: get_presigned_url
# Definition: ToolDefinition(name='get_presigned_url', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'filename': {'type': 'string', 'description': ''}}, 'required': ['collection_id', 'filename'], 'additionalProperties': False}, description='Get a presigned URL for uploading a document to a collection')
# --------------------------------------------------------------------------------
# Tool: get_documents_indexed
# Definition: ToolDefinition(name='get_documents_indexed', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'limit': {'type': 'string', 'description': 'Limit the number of documents to return.', 'default': 1000}, 'nextToken': {'type': 'string', 'description': 'Token for pagination.'}, 'documentId': {'type': 'string', 'description': 'ID of the document to filter by (sort key - single value only). This will take precedence over other filters.'}, 'documentNameContains': {'type': 'string', 'description': "Name of the documents to filter by. Supports multiple values with OR logic. The filter is case-sensitive and supports partial matches using the 'contains' operator."}}, 'required': ['collection_id'], 'additionalProperties': False}, description='List indexed documents in a collection')
# --------------------------------------------------------------------------------
# Tool: get_document_uploaded
# Definition: ToolDefinition(name='get_document_uploaded', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'limit': {'type': 'string', 'description': 'Limit the number of documents to return.', 'default': 1000}, 'nextToken': {'type': 'string', 'description': 'Token for pagination.'}, 'documentId': {'type': 'string', 'description': 'ID of the document to filter by (sort key - single value only). This will take precedence over other filters.'}, 'documentNameContains': {'type': 'string', 'description': "Name of the documents to filter by. Supports multiple values with OR logic. The filter is case-sensitive and supports partial matches using the 'contains' operator."}}, 'required': ['collection_id'], 'additionalProperties': False}, description='List manually uploaded documents in a collection')
# --------------------------------------------------------------------------------
# Tool: get_document_content
# Definition: ToolDefinition(name='get_document_content', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'document_id': {'type': 'string', 'description': ''}, 'limit': {'type': 'integer', 'description': 'Limit the number of characters to return. 0 returns all content.', 'default': 0, 'minimum': 0}, 'nextToken': {'type': 'integer', 'description': 'Character offset for pagination.', 'default': 0, 'minimum': 0}}, 'required': ['collection_id', 'document_id'], 'additionalProperties': False}, description='Get the content of a document in a collection')
# --------------------------------------------------------------------------------
# Tool: get_document_fragments
# Definition: ToolDefinition(name='get_document_fragments', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'document_id': {'type': 'string', 'description': ''}, 'limit': {'type': 'string', 'description': 'Limit the number of fragments to return.', 'default': 1000}, 'nextToken': {'type': 'string', 'description': 'Token for pagination (offset-based).'}}, 'required': ['collection_id', 'document_id'], 'additionalProperties': False}, description='Get the fragments of a document in a collection')
# --------------------------------------------------------------------------------
# Tool: get_index_runs
# Definition: ToolDefinition(name='get_index_runs', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'taskStatus': {'type': 'string', 'description': 'Task status(es) - supports multiple values'}, 'nextToken': {'type': 'string', 'description': 'Next token for pagination'}, 'limit': {'type': 'string', 'description': 'Limit for pagination'}}, 'required': ['collection_id'], 'additionalProperties': False}, description='List index runs in a collection')
# --------------------------------------------------------------------------------
# Tool: get_index_run_tasks
# Definition: ToolDefinition(name='get_index_run_tasks', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'index_run_id': {'type': 'string', 'description': ''}, 'taskStatus': {'type': 'string', 'description': 'Task status(es) - supports multiple values'}, 'nextToken': {'type': 'string', 'description': 'Next token for pagination'}, 'limit': {'type': 'string', 'description': 'Limit for pagination'}, 'task': {'type': 'string', 'description': 'Task type(s) - supports multiple values'}, 'datetimeExecution': {'type': 'string', 'description': 'ISO datetime of when the run was executed'}, 'sourceId': {'type': 'string', 'description': 'ID(s) of the source - supports multiple values'}, 'documentId': {'type': 'string', 'description': 'ID(s) of the document - supports multiple values'}}, 'required': ['collection_id', 'index_run_id'], 'additionalProperties': False}, description='List tasks of an index runs in a collection')
# --------------------------------------------------------------------------------
# Tool: get_index_run_progress
# Definition: ToolDefinition(name='get_index_run_progress', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'index_run_id': {'type': 'string', 'description': ''}}, 'required': ['collection_id', 'index_run_id'], 'additionalProperties': False}, description='Get progress of an active index run in a collection')
# --------------------------------------------------------------------------------
# Tool: get_index_run_token_usage
# Definition: ToolDefinition(name='get_index_run_token_usage', parameters_json_schema={'type': 'object', 'properties': {'collection_id': {'type': 'string', 'description': ''}, 'index_run_id': {'type': 'string', 'description': ''}, 'showDetails': {'type': 'string', 'description': 'Whether to include detailed usage records in the response'}}, 'required': ['collection_id', 'index_run_id'], 'additionalProperties': False}, description='Get token usage of an index runs in a collection')
# --------------------------------------------------------------------------------
# Tool: get_permissions
# Definition: ToolDefinition(name='get_permissions', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'description': 'Name of the resource'}}, 'required': ['resource_type', 'resource_name'], 'additionalProperties': False}, description='Retrieve all user-manageable permissions associated with a resource.\n\nThis API provides a list of roles defined for the given resource, where\neach role includes the users associated with it and the set of\npermissions they are granted.  The permissions returned are limited to\nthose that users can manage directly.\n\nArgs:\n    resource_type (str):\n        The type or category of the resource (e.g., "document",\n        "project").\n    request (ResourceRequest):\n        The request object containing the resource name for which\n        permissions are requested.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nReturns:\n    list[RoleData]: A list of roles for the resource; each role includes\n    the role name, list of member users, and list of permissions with\n    their granted status.\n\nRaises:\n    HTTPException: 404\n        if the resource type is not defined or if the permissions for\n        the resource do not exist.')
# --------------------------------------------------------------------------------
# Tool: add_role
# Definition: ToolDefinition(name='add_role', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}}, 'required': ['resource_type', 'resource_name', 'role'], 'additionalProperties': False}, description="Add a new role to a specified resource.\n\nThis function creates a new role associated with a given resource type\nand resource name. The new role is initialized without any users or\npermissions assigned, except for the default permissions specified in\nthe model's new_role_permissions.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource to which the role will be\n        added.\n    request (RoleRequest):\n        The request object containing the resource name and role name.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 404\n        if the resource type is not defined or the resource permissions\n        do not exist.\n    HTTPException: 422\n        if a role with the specified name already exists for the\n        resource.")
# --------------------------------------------------------------------------------
# Tool: remove_role
# Definition: ToolDefinition(name='remove_role', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}}, 'required': ['resource_type', 'resource_name', 'role'], 'additionalProperties': False}, description='Remove a role from a specified resource.\n\nThis function removes the given role from the identified resource type\nand resource name. Note that the owner role is protected and cannot be\nremoved; attempting to do so will result in an HTTP 422 error.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource from which the role will be\n        removed.\n    request (RoleRequest):\n        The request object containing the resource name and role name.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 404\n        if the resource type is not defined, the resource permissions do\n        not exist, or the role does not exist.\n    HTTPException: 422\n        if an attempt is made to remove the owner role, which is not\n        permitted.')
# --------------------------------------------------------------------------------
# Tool: grant_permission
# Definition: ToolDefinition(name='grant_permission', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'permission': {'type': 'string', 'title': 'Permission', 'description': 'ID of the permission to add or remove'}}, 'required': ['resource_type', 'resource_name', 'role', 'permission'], 'additionalProperties': False}, description='Grant a specific permission to a role on a given resource.\n\nThis function grants a permission identified by its scope name to a\nspecified role, on a particular resource type and resource name.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource to which the permission\n        applies.\n    request (PermissionRoleRequest):\n        The request containing the resource name, role name, and\n        permission ID to be granted.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 404 if the resource permissions do not exist or the\n        role does not exist.\n    HTTPException: 422 if the permission is not defined, not\n        user-manageable, or is already granted to the role.')
# --------------------------------------------------------------------------------
# Tool: revoke_permission
# Definition: ToolDefinition(name='revoke_permission', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'permission': {'type': 'string', 'title': 'Permission', 'description': 'ID of the permission to add or remove'}}, 'required': ['resource_type', 'resource_name', 'role', 'permission'], 'additionalProperties': False}, description='Revoke a specific permission from a role on given resource.\n\nThis function removes a previously granted permission from a role on a\nparticular resource type and resource name.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource from which the permission is\n        to be revoked.\n    request (PermissionRoleRequest):\n        The request object containing the resource name, role name, and\n        permission ID to be revoked.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 404 if the resource permissions do not exist or the\n        role does not exist.\n    HTTPException: 422 if the permission is not defined, not\n        user-manageable, or is not currently granted to the role on the\n        resource.')
# --------------------------------------------------------------------------------
# Tool: add_user
# Definition: ToolDefinition(name='add_user', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'user': {'type': 'string', 'title': 'User', 'description': 'Username of the user'}}, 'required': ['resource_type', 'resource_name', 'role', 'user'], 'additionalProperties': False}, description="Add a user to a specific role on a given resource.\n\nThis function associates the specified user with a role on a resource,\nenabling them to access or manage that resource according to the role's\npermissions.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource (e.g., project, team,\n        application).\n    request (UserRoleRequest):\n        The request object containing the resource name, role name, and\n        username.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 422 if the user is already a member of the specified\n    role on the given resource.")
# --------------------------------------------------------------------------------
# Tool: remove_user
# Definition: ToolDefinition(name='remove_user', parameters_json_schema={'type': 'object', 'properties': {'resource_type': {'type': 'string', 'description': ''}, 'resource_name': {'type': 'string', 'title': 'Resource Name', 'description': 'Name of the resource'}, 'role': {'type': 'string', 'title': 'Role', 'description': 'Name of the role to update'}, 'user': {'type': 'string', 'title': 'User', 'description': 'Username of the user'}}, 'required': ['resource_type', 'resource_name', 'role', 'user'], 'additionalProperties': False}, description='Remove a user from a specific role on a given resource.\n\nThis function removes the specified user from the given role on the\ngiven resource.  The user will no longer have the permissions associated\nwith that role for the resource, unless they have those permissions\nthrough another role.\n\nNote that a user is not allowed to remove themselves from the owner role\nto prevent accidental loss of ownership. Additionally, the owner role\nmust always have at least one member.\n\nArgs:\n    resource_type (str):\n        The type/category of the resource (e.g., project, repository).\n    request (UserRoleRequest):\n        The request object containing the resource name, role name, and\n        username.\n    userauth (UserAuthorization):\n        The user authorization object for permission checking.\n\nRaises:\n    HTTPException: 404\n        if the resource permissions do not exist or the role does not\n        exist.\n    HTTPException: 422\n        if the user is not currently assigned to the role, if attempting\n        to remove oneself from the owner role, or if attempting to\n        remove the last member from the owner role.')
# --------------------------------------------------------------------------------

# %%
# Step 2: Organize Tools into Groups

# Organize tools by functionality
tool_groups = {
    "sources": [],      # Source management
    "documents": [],    # Document operations
    "search": [],       # Search and query functionality
    "retrieval": [],    # RAG and retrieval operations
    "processing": [],   # Document processing and ingestion
    "metadata": [],     # Metadata and tagging
    "collections": [],  # Collection management
    "indexing": [],     # Indexing and vector operations
    "permissions": [],  # Permission and access control
    "admin": [],        # Administrative operations
    "other": []         # Miscellaneous
}

# Define specific tool name patterns for categorization
source_patterns = ["source", "sources"]
document_patterns = ["document", "documents", "doc"]
search_patterns = ["search", "query", "find"]
retrieval_patterns = ["retrieve", "rag", "vector", "embedding"]
processing_patterns = ["process", "ingest", "parse", "extract"]
metadata_patterns = ["metadata", "tag", "label", "annotation"]
collection_patterns = ["collection", "collections"]
indexing_patterns = ["index", "indexing", "reindex", "vector", "embedding"]
permission_patterns = ["permission", "permissions", "access", "auth", "role", "acl"]
admin_patterns = ["admin", "user", "config", "health", "status"]

for tool in tools:
    name_lower = tool.name.lower()
    
    # Check patterns in order of specificity
    if any(pattern in name_lower for pattern in source_patterns):
        tool_groups["sources"].append(tool)
    elif any(pattern in name_lower for pattern in document_patterns):
        tool_groups["documents"].append(tool)
    elif any(pattern in name_lower for pattern in search_patterns):
        tool_groups["search"].append(tool)
    elif any(pattern in name_lower for pattern in collection_patterns):
        tool_groups["collections"].append(tool)
    elif any(pattern in name_lower for pattern in indexing_patterns):
        tool_groups["indexing"].append(tool)
    elif any(pattern in name_lower for pattern in permission_patterns):
        tool_groups["permissions"].append(tool)
    elif any(pattern in name_lower for pattern in retrieval_patterns):
        tool_groups["retrieval"].append(tool)
    elif any(pattern in name_lower for pattern in processing_patterns):
        tool_groups["processing"].append(tool)
    elif any(pattern in name_lower for pattern in metadata_patterns):
        tool_groups["metadata"].append(tool)
    elif any(pattern in name_lower for pattern in admin_patterns):
        tool_groups["admin"].append(tool)
    else:
        tool_groups["other"].append(tool)

# Display the groups and their tools
print("\n📊 AI Knowledge Tool Groups Summary:\n")
for group_name, group_tools in tool_groups.items():
    print(f"{group_name.upper()}: {len(group_tools)} tools")
    for tool in group_tools:
        print(f"  • {tool.name}")
    print()
# Out:
# 📊 AI Knowledge Tool Groups Summary:
#
# SOURCES: 5 tools
#   • list_sources
#   • create_source
#   • get_source_configuration
#   • update_source
#   • delete_source
#
# DOCUMENTS: 5 tools
#   • delete_document
#   • get_documents_indexed
#   • get_document_uploaded
#   • get_document_content
#   • get_document_fragments
#
# SEARCH: 1 tools
#   • query
#
# RETRIEVAL: 1 tools
#   • get_fragment_counts
#
# PROCESSING: 0 tools
#
# METADATA: 0 tools
#
# COLLECTIONS: 7 tools
#   • list_collections
#   • create_collection
#   • get_collection_configuration
#   • update_collection
#   • delete_collection
#   • index_collection
#   • get_collection_usage
#
# INDEXING: 4 tools
#   • get_index_runs
#   • get_index_run_tasks
#   • get_index_run_progress
#   • get_index_run_token_usage
#
# PERMISSIONS: 5 tools
#   • get_permissions
#   • add_role
#   • remove_role
#   • grant_permission
#   • revoke_permission
#
# ADMIN: 3 tools
#   • health_check
#   • add_user
#   • remove_user
#
# OTHER: 6 tools
#   • check_connection_s3
#   • check_connection_github
#   • check_connection_website
#   • info
#   • available_models
#   • get_presigned_url
